# %%
import pandas as pd
import numpy as np
import random

# %%
df = pd.read_csv("iwp_start.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'CustomerName', 'PaymentID',
#        'PaymentDate', 'InvoiceID', 'InvoiceDate', 'PaymentAmt', 'SalesOrderID',
#        'Department', 'AccountDesc', 'CostCenter', 'MinorityOwned',
#        'SmallBusiness', 'WomenOwned', 'City', 'State', 'Zip', 'Country',
#        'CustomerId', 'DaysOutstanding', 'CompliantIndicator'],
#       dtype='object')

# %%
df.drop(columns=['Unnamed: 0.1', 'Unnamed: 0'],inplace=True)

# %%
df['SalesOrderID'] = df['SalesOrderID'].replace(np.nan,random.randint(600000,600100))

# %%
df['SalesOrderID'] = df['SalesOrderID'].apply(np.int64)

# %%
df['SalesOrderID'] = df['SalesOrderID'].replace(np.nan,random.randint(700000,700100))

# %%
df['CostCenter'] = df['CostCenter'].replace(np.nan,random.randint(700200,700300))

# %%
df['PaymentAmt'] = df['PaymentAmt'].apply(np.float64)

# %%
df['PaymentDate'] = pd.to_datetime(df['PaymentDate'])

# %%
df.query('InvoiceDate.str.contains("141")')
#df.drop(df.index[df['InvoiceDate']=='23975'],inplace=True)
# Out:
# Empty DataFrame
# Columns: [CustomerName, PaymentID, PaymentDate, InvoiceID, InvoiceDate, PaymentAmt, SalesOrderID, Department, AccountDesc, CostCenter, MinorityOwned, SmallBusiness, WomenOwned, City, State, Zip, Country, CustomerId, DaysOutstanding, CompliantIndicator]
# Index: []

# %%
df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

# %%
df
# Out:
#                                CustomerName  PaymentID PaymentDate  \
# 0              Tempest Telcom Solutions LLC    2175536  2018-04-19
# 1                      Ram Tool & Supply Co    2115145  2015-01-07
# 2                    OutSource Staffing LLC    2174138  2018-03-23
# 3         Unum Life Insurance Co of America    2126670  2015-08-06
# 4                   Canon Solutions America    2176309  2018-05-07
# ...                                     ...        ...         ...
# 510992              Canon Solutions America    2212752  2020-11-25
# 510993               Tenn Waste Haulers LLC    2110002  2014-09-26
# 510994              Hixson Utility District    2212688  2020-11-23
# 510995          Chatt Business Machines Inc    2145164  2016-07-20
# 510996  Electric Power Board of Chattanooga    2181539  2018-08-31
#
#                            InvoiceID InvoiceDate  PaymentAmt  SalesOrderID  \
# 0                             123204  2018-04-12     1995.00        548218
# 1                           92236320  2014-10-31      172.68        525868
# 2                              37534  2018-02-27     3620.74        545788
# 3       3rdM-06-AUG-15-211646-326520  2015-08-06       58.80        600097
# 4                           18559368  2018-04-30      175.22        526878
# ...                              ...         ...         ...           ...
# 510992                      22063578  2020-10-31       41.55        552282
# 510993                         85652  2014-08-31      483.50        512164
# 510994              74000640-00 1120  2020-11-06      172.83        554981
# 510995                        055173  2016-06-28     1010.00        511155
# 510996               2620137000 0818  2018-08-23     2679.75        549978
#
#                         Department                   AccountDesc  \
# 0                             Fire              Electronic Parts
# 1                     Public Works  Hardware, Nails, Small Tools
# 2       Youth & Family Development           Employment Agencies
# 3                        Undefined             AP Long Term Care
# 4                     Public Works         Office Machine Rental
# ...                            ...                           ...
# 510992  Youth & Family Development         Office Machine Rental
# 510993                Public Works                Waste Disposal
# 510994                        Fire                         Sewer
# 510995                Public Works          Maintenance Services
# 510996  Youth & Family Development                   Electricity
#
#                                CostCenter MinorityOwned SmallBusiness  \
# 0       TN Valley Regional Communications            No            No
# 1                     CWS Street Cleaning            No            No
# 2                        Recreation Admin            No            No
# 3                            Not Required            No            No
# 4                         ISS Engineering            No            No
# ...                                   ...           ...           ...
# 510992                   Early Head Start            No            No
# 510993                          CWS Admin            No            No
# 510994                  Fire Station # 22            No            No
# 510995                      City Engineer            No            No
# 510996                 Head Start Centers            No            No
#
#        WomenOwned            City State         Zip Country  CustomerId  \
# 0             Yes  Santa Barbara,   CA,       93101      US        7558
# 1              No     Birmingham,   AL,  35232-0979      US         547
# 2              No    Chattanooga,   TN,       37424      US        4198
# 3              No        Atlanta,   GA,  30384-6990      US        8581
# 4              No        Chicago,   IL,  60693-0149      US      190422
# ...           ...             ...   ...         ...     ...         ...
# 510992         No        Chicago,   IL,  60693-0149      US      190422
# 510993         No    Chattanooga,   TN,  37416-6155      US        3443
# 510994         No         Hixson,   TN,  37343-5598      US         150
# 510995         No    Chattanooga,   TN,  37422-4355      US         596
# 510996         No    Chattanooga,   TN,  37422-7254      US          91
#
#         DaysOutstanding CompliantIndicator
# 0                     7                Yes
# 1                    68                 No
# 2                    24                Yes
# 3                     0                Yes
# 4                     7                Yes
# ...                 ...                ...
# 510992               25                Yes
# 510993               26                Yes
# 510994               17                Yes
# 510995               22                Yes
# 510996                8                Yes
#
# [510997 rows x 20 columns]

# %%
df['DSO'] = (df['PaymentDate']-df['InvoiceDate']).dt.days

# %%
df
# Out:
#                                CustomerName  PaymentID PaymentDate  \
# 0              Tempest Telcom Solutions LLC    2175536  2018-04-19
# 1                      Ram Tool & Supply Co    2115145  2015-01-07
# 2                    OutSource Staffing LLC    2174138  2018-03-23
# 3         Unum Life Insurance Co of America    2126670  2015-08-06
# 4                   Canon Solutions America    2176309  2018-05-07
# ...                                     ...        ...         ...
# 510992              Canon Solutions America    2212752  2020-11-25
# 510993               Tenn Waste Haulers LLC    2110002  2014-09-26
# 510994              Hixson Utility District    2212688  2020-11-23
# 510995          Chatt Business Machines Inc    2145164  2016-07-20
# 510996  Electric Power Board of Chattanooga    2181539  2018-08-31
#
#                            InvoiceID InvoiceDate  PaymentAmt  SalesOrderID  \
# 0                             123204  2018-04-12     1995.00        548218
# 1                           92236320  2014-10-31      172.68        525868
# 2                              37534  2018-02-27     3620.74        545788
# 3       3rdM-06-AUG-15-211646-326520  2015-08-06       58.80        600097
# 4                           18559368  2018-04-30      175.22        526878
# ...                              ...         ...         ...           ...
# 510992                      22063578  2020-10-31       41.55        552282
# 510993                         85652  2014-08-31      483.50        512164
# 510994              74000640-00 1120  2020-11-06      172.83        554981
# 510995                        055173  2016-06-28     1010.00        511155
# 510996               2620137000 0818  2018-08-23     2679.75        549978
#
#                         Department                   AccountDesc  \
# 0                             Fire              Electronic Parts
# 1                     Public Works  Hardware, Nails, Small Tools
# 2       Youth & Family Development           Employment Agencies
# 3                        Undefined             AP Long Term Care
# 4                     Public Works         Office Machine Rental
# ...                            ...                           ...
# 510992  Youth & Family Development         Office Machine Rental
# 510993                Public Works                Waste Disposal
# 510994                        Fire                         Sewer
# 510995                Public Works          Maintenance Services
# 510996  Youth & Family Development                   Electricity
#
#                                CostCenter  ... SmallBusiness WomenOwned  \
# 0       TN Valley Regional Communications  ...            No        Yes
# 1                     CWS Street Cleaning  ...            No         No
# 2                        Recreation Admin  ...            No         No
# 3                            Not Required  ...            No         No
# 4                         ISS Engineering  ...            No         No
# ...                                   ...  ...           ...        ...
# 510992                   Early Head Start  ...            No         No
# 510993                          CWS Admin  ...            No         No
# 510994                  Fire Station # 22  ...            No         No
# 510995                      City Engineer  ...            No         No
# 510996                 Head Start Centers  ...            No         No
#
#                   City State         Zip Country CustomerId  DaysOutstanding  \
# 0       Santa Barbara,   CA,       93101      US       7558                7
# 1          Birmingham,   AL,  35232-0979      US        547               68
# 2         Chattanooga,   TN,       37424      US       4198               24
# 3             Atlanta,   GA,  30384-6990      US       8581                0
# 4             Chicago,   IL,  60693-0149      US     190422                7
# ...                ...   ...         ...     ...        ...              ...
# 510992        Chicago,   IL,  60693-0149      US     190422               25
# 510993    Chattanooga,   TN,  37416-6155      US       3443               26
# 510994         Hixson,   TN,  37343-5598      US        150               17
# 510995    Chattanooga,   TN,  37422-4355      US        596               22
# 510996    Chattanooga,   TN,  37422-7254      US         91                8
#
#         CompliantIndicator DSO
# 0                      Yes   7
# 1                       No  68
# 2                      Yes  24
# 3                      Yes   0
# 4                      Yes   7
# ...                    ...  ..
# 510992                 Yes  25
# 510993                 Yes  26
# 510994                 Yes  17
# 510995                 Yes  22
# 510996                 Yes   8
#
# [510997 rows x 21 columns]

# %%
replace = df.Department.value_counts().argmax()
df['Department'].fillna(replace, inplace=True) 
df['Department'] = df['Department'].astype('str')

replace = df.MinorityOwned.value_counts().argmax()
df['MinorityOwned'].fillna(replace, inplace=True)
df['MinorityOwned'] = df['MinorityOwned'].astype('str')

replace = df.SmallBusiness.value_counts().argmax()
df['SmallBusiness'].fillna(replace, inplace=True) 
df['SmallBusiness'] = df['SmallBusiness'].astype('str')

replace = df.WomenOwned.value_counts().argmax()
df['WomenOwned'].fillna(replace, inplace=True)
df['WomenOwned'] = df['WomenOwned'].astype('str')

replace = df.City.value_counts().argmax()
df['City'].fillna(replace, inplace=True) 
df['City'] = df['City'].astype('str')

replace = df.State.value_counts().argmax()
df['State'].fillna(replace, inplace=True)
df['State'] = df['State'].astype('str')

replace = df.Country.value_counts().argmax()
df['Country'].fillna(replace, inplace=True) 
df['Country'] = df['Country'].astype('str')

replace = df.CompliantIndicator.value_counts().argmax()
df['CompliantIndicator'].fillna(replace, inplace=True) 
df['CompliantIndicator'] = df['CompliantIndicator'].astype('str')

# %%
df_final = df[['PaymentDate','InvoiceDate','PaymentAmt','Department','MinorityOwned','SmallBusiness','WomenOwned','City','State','Country','CompliantIndicator','DSO']]

# %%
df_final.to_csv('iwp_end.csv')
